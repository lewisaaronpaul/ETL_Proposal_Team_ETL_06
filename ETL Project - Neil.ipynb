# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
import requests
import re
import nbconvert
import time
import os
import numpy as np

# %%
# Activate splinter
executable_path = {'executable_path': r'C:\Users\nvora\AppData\Roaming\chromedriver_win32\chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Set Web Scrape URL

unemployment_url = "https://data.ers.usda.gov/reports.aspx?ID=17828"

# %%
# Scrape Data for each State to acquire county level data - Download each file as a CSV
### Note - I tried to scrape the data directly from the HTML itself but the URL for this site does not change when you query different data 
#### Using Splinter I was at least able to scrape all the data
list_of_states = [
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 
                  'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
                  'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 
                  'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 
                  'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 
                  'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 
                  'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 
                  'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
# Use Splinter to click through each State and download the associated data to Excel

for state in list_of_states:
    browser.visit(unemployment_url)
    time.sleep(6)
    browser.click_link_by_partial_text(state)
    time.sleep(3)
    browser.click_link_by_id('ctl00_MainContentPlaceHolder_reportingServicesWrapper1__reportViewer_ctl05_ctl04_ctl00')
    time.sleep(2)
    browser.click_link_by_partial_text('Excel')
    time.sleep(1)
# Out:
# C:\Users\nvora\Anaconda3\envs\PythonData\lib\site-packages\splinter-0.14.0-py3.8.egg\splinter\driver\webdriver\__init__.py:490: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.

# %%
# Read all of the scraped excel files into a list of dataframes

list_of_dfs = []

for x in range(len(list_of_states)):
    filepath = os.path.join(f'Data_Files/UnemploymentReport ({x}).xlsx')
    state_df = pd.read_excel(filepath,header=1)
    list_of_dfs.append(state_df)

# %%
# Concatenate the list of dataframes into a single dataframe with all states and counties

unemployment_df = pd.concat(list_of_dfs)

unemployment_df
# Out:
#                                                 FIPS                  Name  \
# 0                                               01000              Alabama
# 1                                               01001   Autauga County, AL
# 2                                               01003   Baldwin County, AL
# 3                                               01005   Barbour County, AL
# 4                                               01007      Bibb County, AL
# ..                                                ...                  ...
# 21                                              56041     Uinta County, WY
# 22                                              56043  Washakie County, WY
# 23                                              56045    Weston County, WY
# 24                                                NaN                  NaN
# 25  Sources: Bureau of Labor Statistics, Local Are...                  NaN
#
#     2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# 0    9.6   8.0   7.2   6.8   6.1   5.8   4.4   3.9   3.0
# 1    8.4   6.9   6.2   5.8   5.2   5.1   3.9   3.6   2.7
# 2    9.0   7.5   6.6   6.1   5.5   5.3   4.1   3.6   2.7
# 3   11.5  11.5  10.2  10.5   8.9   8.3   5.8   5.1   3.8
# 4   10.5   8.5   7.9   7.2   6.6   6.4   4.4   3.9   3.1
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 21   6.2   5.6   5.3   4.8   5.1   5.8   4.5   4.2   3.9
# 22   5.6   5.2   5.0   4.3   4.2   4.8   4.0   4.1   3.9
# 23   4.6   4.1   3.6   3.3   3.4   5.0   3.9   3.3   2.9
# 24   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     Median Household Income (2018)  % of State Median HH Income
# 0                          49881.0                     1.000000
# 1                          59338.0                     1.189591
# 2                          57588.0                     1.154508
# 3                          34382.0                     0.689280
# 4                          46064.0                     0.923478
# ..                             ...                          ...
# 21                         63401.0                     1.018343
# 22                         55190.0                     0.886458
# 23                         54319.0                     0.872468
# 24                             NaN                          NaN
# 25                             NaN                          NaN
#
# [3373 rows x 13 columns]

# %%
## DATA CLEANING

# %%
# Strip the leading 0 in FIPS code and rename FIPS to remove empty space

unemployment_df['FIPS '] = unemployment_df['FIPS '].astype(str) 


unemployment_df['FIPS '] = [fips.lstrip('0') for fips in unemployment_df['FIPS ']]

unemployment_df = unemployment_df.rename(columns={'FIPS ':'FIPS'})

unemployment_df
# Out:
#                                                  FIPS                 Name  \
# 0                                                1000              Alabama
# 1                                                1001   Autauga County, AL
# 2                                                1003   Baldwin County, AL
# 3                                                1005   Barbour County, AL
# 4                                                1007      Bibb County, AL
# ..                                                ...                  ...
# 21                                              56041     Uinta County, WY
# 22                                              56043  Washakie County, WY
# 23                                              56045    Weston County, WY
# 24                                                nan                  NaN
# 25  Sources: Bureau of Labor Statistics, Local Are...                  NaN
#
#     2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# 0    9.6   8.0   7.2   6.8   6.1   5.8   4.4   3.9   3.0
# 1    8.4   6.9   6.2   5.8   5.2   5.1   3.9   3.6   2.7
# 2    9.0   7.5   6.6   6.1   5.5   5.3   4.1   3.6   2.7
# 3   11.5  11.5  10.2  10.5   8.9   8.3   5.8   5.1   3.8
# 4   10.5   8.5   7.9   7.2   6.6   6.4   4.4   3.9   3.1
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 21   6.2   5.6   5.3   4.8   5.1   5.8   4.5   4.2   3.9
# 22   5.6   5.2   5.0   4.3   4.2   4.8   4.0   4.1   3.9
# 23   4.6   4.1   3.6   3.3   3.4   5.0   3.9   3.3   2.9
# 24   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     Median Household Income (2018)  % of State Median HH Income
# 0                          49881.0                     1.000000
# 1                          59338.0                     1.189591
# 2                          57588.0                     1.154508
# 3                          34382.0                     0.689280
# 4                          46064.0                     0.923478
# ..                             ...                          ...
# 21                         63401.0                     1.018343
# 22                         55190.0                     0.886458
# 23                         54319.0                     0.872468
# 24                             NaN                          NaN
# 25                             NaN                          NaN
#
# [3373 rows x 13 columns]

# %%
## Separate the data into two DataFrames - one with State level data, and one with County Level Data
# County DataFrame

county_unemployment_df = unemployment_df[~unemployment_df['Name'].isin(list_of_states)].dropna()

county_unemployment_df
# Out:
#      FIPS                   Name  2011  2012  2013  2014  2015  2016  2017  \
# 1    1001     Autauga County, AL   8.4   6.9   6.2   5.8   5.2   5.1   3.9
# 2    1003     Baldwin County, AL   9.0   7.5   6.6   6.1   5.5   5.3   4.1
# 3    1005     Barbour County, AL  11.5  11.5  10.2  10.5   8.9   8.3   5.8
# 4    1007        Bibb County, AL  10.5   8.5   7.9   7.2   6.6   6.4   4.4
# 5    1009      Blount County, AL   8.7   6.9   6.3   6.1   5.4   5.4   4.0
# ..    ...                    ...   ...   ...   ...   ...   ...   ...   ...
# 19  56037  Sweetwater County, WY   5.3   4.8   4.4   4.0   4.8   6.1   4.5
# 20  56039       Teton County, WY   7.5   6.7   5.6   4.6   3.9   3.5   2.8
# 21  56041       Uinta County, WY   6.2   5.6   5.3   4.8   5.1   5.8   4.5
# 22  56043    Washakie County, WY   5.6   5.2   5.0   4.3   4.2   4.8   4.0
# 23  56045      Weston County, WY   4.6   4.1   3.6   3.3   3.4   5.0   3.9
#
#     2018  2019  Median Household Income (2018)  % of State Median HH Income
# 1    3.6   2.7                         59338.0                     1.189591
# 2    3.6   2.7                         57588.0                     1.154508
# 3    5.1   3.8                         34382.0                     0.689280
# 4    3.9   3.1                         46064.0                     0.923478
# 5    3.5   2.7                         50412.0                     1.010645
# ..   ...   ...                             ...                          ...
# 19   4.0   3.9                         73315.0                     1.177581
# 20   2.9   2.7                         99087.0                     1.591529
# 21   4.2   3.9                         63401.0                     1.018343
# 22   4.1   3.9                         55190.0                     0.886458
# 23   3.3   2.9                         54319.0                     0.872468
#
# [3135 rows x 13 columns]

# %%
# Remove the State abbreviations from the name to match the county names with the other tables

county_unemployment_df['County'] = county_unemployment_df['Name'].str.split(',').str[0].drop(columns='Name',axis=1)

county_unemployment_df['Name'] = county_unemployment_df['County']

county_unemployment_df = county_unemployment_df.drop(columns='County',axis=1).rename(columns={'Name':'county'})

county_unemployment_df
# Out:
#      FIPS             county  2011  2012  2013  2014  2015  2016  2017  2018  \
# 1    1001     Autauga County   8.4   6.9   6.2   5.8   5.2   5.1   3.9   3.6
# 2    1003     Baldwin County   9.0   7.5   6.6   6.1   5.5   5.3   4.1   3.6
# 3    1005     Barbour County  11.5  11.5  10.2  10.5   8.9   8.3   5.8   5.1
# 4    1007        Bibb County  10.5   8.5   7.9   7.2   6.6   6.4   4.4   3.9
# 5    1009      Blount County   8.7   6.9   6.3   6.1   5.4   5.4   4.0   3.5
# ..    ...                ...   ...   ...   ...   ...   ...   ...   ...   ...
# 19  56037  Sweetwater County   5.3   4.8   4.4   4.0   4.8   6.1   4.5   4.0
# 20  56039       Teton County   7.5   6.7   5.6   4.6   3.9   3.5   2.8   2.9
# 21  56041       Uinta County   6.2   5.6   5.3   4.8   5.1   5.8   4.5   4.2
# 22  56043    Washakie County   5.6   5.2   5.0   4.3   4.2   4.8   4.0   4.1
# 23  56045      Weston County   4.6   4.1   3.6   3.3   3.4   5.0   3.9   3.3
#
#     2019  Median Household Income (2018)  % of State Median HH Income
# 1    2.7                         59338.0                     1.189591
# 2    2.7                         57588.0                     1.154508
# 3    3.8                         34382.0                     0.689280
# 4    3.1                         46064.0                     0.923478
# 5    2.7                         50412.0                     1.010645
# ..   ...                             ...                          ...
# 19   3.9                         73315.0                     1.177581
# 20   2.7                         99087.0                     1.591529
# 21   3.9                         63401.0                     1.018343
# 22   3.9                         55190.0                     0.886458
# 23   2.9                         54319.0                     0.872468
#
# [3135 rows x 13 columns]

# %%
# Narrow Down Columns to relevant/more recent data & rename Unemployment Column

county_unemployment_df = county_unemployment_df[['FIPS','county','2019','Median Household Income (2018)','% of State Median HH Income']]

county_unemployment_df = county_unemployment_df.rename(columns={'2019':'Latest Annual Unemployment Rate (2019)'})

# %%
county_unemployment_df.head()
# Out:
#    FIPS          county  Latest Annual Unemployment Rate (2019)  \
# 1  1001  Autauga County                                     2.7
# 2  1003  Baldwin County                                     2.7
# 3  1005  Barbour County                                     3.8
# 4  1007     Bibb County                                     3.1
# 5  1009   Blount County                                     2.7
#
#    Median Household Income (2018)  % of State Median HH Income
# 1                         59338.0                     1.189591
# 2                         57588.0                     1.154508
# 3                         34382.0                     0.689280
# 4                         46064.0                     0.923478
# 5                         50412.0                     1.010645

# %%
## Separate the data into two DataFrames - one with State level data, and one with County Level Data
# State Dataframe
state_unemployment_df = unemployment_df[unemployment_df['Name'].isin(list_of_states)]

# District of Columbia appeared twice in this dataframe because the county name is also the state name
state_unemployment_df = state_unemployment_df.drop_duplicates('Name')

# %%
# Narrow down columns and rename columns like above

state_unemployment_df = state_unemployment_df[['FIPS','Name','2019','Median Household Income (2018)','% of State Median HH Income']].rename(columns={'Name':'State','2019':'Latest Annual Unemployment Rate (2019)'})

# %%
state_unemployment_df.head()
# Out:
#    FIPS       State  Latest Annual Unemployment Rate (2019)  \
# 0  1000     Alabama                                     3.0
# 0  2000      Alaska                                     6.1
# 0  4000     Arizona                                     4.7
# 0  5000    Arkansas                                     3.5
# 0  6000  California                                     4.0
#
#    Median Household Income (2018)  % of State Median HH Income
# 0                         49881.0                          1.0
# 0                         74912.0                          1.0
# 0                         59079.0                          1.0
# 0                         47094.0                          1.0
# 0                         75250.0                          1.0

# %%
# Read in county voter data

##    Had to set dtype as str - the file was loading all numbers (including FIPS) with .0 attached
voter_df = pd.read_csv('Data_Files/countypres_2000-2016.csv',dtype=str)

voter_df.head()
# Out:
#    year    state state_po   county  FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001  President           Other
# 4  2000  Alabama       AL  Baldwin  1003  President         Al Gore
#
#         party candidatevotes totalvotes   version
# 0    democrat           4942      17208  20191203
# 1  republican          11993      17208  20191203
# 2       green            160      17208  20191203
# 3         NaN            113      17208  20191203
# 4    democrat          13997      56480  20191203

# %%
## DATA CLEANING

# %%
# Narrow Voter Data to most recent Data

voter_df_2016 = voter_df.loc[voter_df['year']=='2016',:]

# FIll NaN values in party column with Other

voter_df_2016['party'] = voter_df_2016['party'].fillna('Other')

voter_df_2016.head(10)
# Out:
# <ipython-input-19-1e1d4dea5a9f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voter_df_2016['party'] = voter_df_2016['party'].fillna('Other')
#        year    state state_po   county  FIPS     office        candidate  \
# 40517  2016  Alabama       AL  Autauga  1001  President  Hillary Clinton
# 40518  2016  Alabama       AL  Autauga  1001  President     Donald Trump
# 40519  2016  Alabama       AL  Autauga  1001  President            Other
# 40520  2016  Alabama       AL  Baldwin  1003  President  Hillary Clinton
# 40521  2016  Alabama       AL  Baldwin  1003  President     Donald Trump
# 40522  2016  Alabama       AL  Baldwin  1003  President            Other
# 40523  2016  Alabama       AL  Barbour  1005  President  Hillary Clinton
# 40524  2016  Alabama       AL  Barbour  1005  President     Donald Trump
# 40525  2016  Alabama       AL  Barbour  1005  President            Other
# 40526  2016  Alabama       AL     Bibb  1007  President  Hillary Clinton
#
#             party candidatevotes totalvotes   version
# 40517    democrat           5936      24973  20191203
# 40518  republican          18172      24973  20191203
# 40519       Other            865      24973  20191203
# 40520    democrat          18458      95215  20191203
# 40521  republican          72883      95215  20191203
# 40522       Other           3874      95215  20191203
# 40523    democrat           4871      10469  20191203
# 40524  republican           5454      10469  20191203
# 40525       Other            144      10469  20191203
# 40526    democrat           1874       8819  20191203

# %%
# Remove unnecessary columns

voter_df2 = voter_df_2016[['state','county','FIPS','office','party','candidatevotes']]

voter_df2.head(10)
# Out:
#          state   county  FIPS     office       party candidatevotes
# 40517  Alabama  Autauga  1001  President    democrat           5936
# 40518  Alabama  Autauga  1001  President  republican          18172
# 40519  Alabama  Autauga  1001  President       Other            865
# 40520  Alabama  Baldwin  1003  President    democrat          18458
# 40521  Alabama  Baldwin  1003  President  republican          72883
# 40522  Alabama  Baldwin  1003  President       Other           3874
# 40523  Alabama  Barbour  1005  President    democrat           4871
# 40524  Alabama  Barbour  1005  President  republican           5454
# 40525  Alabama  Barbour  1005  President       Other            144
# 40526  Alabama     Bibb  1007  President    democrat           1874

# %%
voter_df3 = voter_df2[['county','party','candidatevotes']]

voter_df3.head(10)
# Out:
#         county       party candidatevotes
# 40517  Autauga    democrat           5936
# 40518  Autauga  republican          18172
# 40519  Autauga       Other            865
# 40520  Baldwin    democrat          18458
# 40521  Baldwin  republican          72883
# 40522  Baldwin       Other           3874
# 40523  Barbour    democrat           4871
# 40524  Barbour  republican           5454
# 40525  Barbour       Other            144
# 40526     Bibb    democrat           1874

# %%
### Rearrange the dataframe to only have a single county row

democrat_df = pd.merge(voter_df_2016['FIPS'],voter_df2.loc[voter_df3['party'] == 'democrat',:],on='FIPS',how='right')

democrat_df = democrat_df.drop_duplicates()

democrat_df.head(10)
# Out:
#     FIPS    state    county     office     party candidatevotes
# 0   1001  Alabama   Autauga  President  democrat           5936
# 3   1003  Alabama   Baldwin  President  democrat          18458
# 6   1005  Alabama   Barbour  President  democrat           4871
# 9   1007  Alabama      Bibb  President  democrat           1874
# 12  1009  Alabama    Blount  President  democrat           2156
# 15  1011  Alabama   Bullock  President  democrat           3530
# 18  1013  Alabama    Butler  President  democrat           3726
# 21  1015  Alabama   Calhoun  President  democrat          13242
# 24  1017  Alabama  Chambers  President  democrat           5784
# 27  1019  Alabama  Cherokee  President  democrat           1547

# %%
democrat_republican_df = pd.merge(democrat_df,voter_df2.loc[voter_df2['party'] == 'republican',:],on=['FIPS'],how='right')

democrat_republican_df = democrat_republican_df.drop_duplicates()

democrat_republican_df.head(15)
# Out:
#     FIPS  state_x  county_x   office_x   party_x candidatevotes_x  state_y  \
# 0   1001  Alabama   Autauga  President  democrat             5936  Alabama
# 1   1003  Alabama   Baldwin  President  democrat            18458  Alabama
# 2   1005  Alabama   Barbour  President  democrat             4871  Alabama
# 3   1007  Alabama      Bibb  President  democrat             1874  Alabama
# 4   1009  Alabama    Blount  President  democrat             2156  Alabama
# 5   1011  Alabama   Bullock  President  democrat             3530  Alabama
# 6   1013  Alabama    Butler  President  democrat             3726  Alabama
# 7   1015  Alabama   Calhoun  President  democrat            13242  Alabama
# 8   1017  Alabama  Chambers  President  democrat             5784  Alabama
# 9   1019  Alabama  Cherokee  President  democrat             1547  Alabama
# 10  1021  Alabama   Chilton  President  democrat             2911  Alabama
# 11  1023  Alabama   Choctaw  President  democrat             3109  Alabama
# 12  1025  Alabama    Clarke  President  democrat             5749  Alabama
# 13  1027  Alabama      Clay  President  democrat             1237  Alabama
# 14  1029  Alabama  Cleburne  President  democrat              684  Alabama
#
#     county_y   office_y     party_y candidatevotes_y
# 0    Autauga  President  republican            18172
# 1    Baldwin  President  republican            72883
# 2    Barbour  President  republican             5454
# 3       Bibb  President  republican             6738
# 4     Blount  President  republican            22859
# 5    Bullock  President  republican             1140
# 6     Butler  President  republican             4901
# 7    Calhoun  President  republican            32865
# 8   Chambers  President  republican             7843
# 9   Cherokee  President  republican             8953
# 10   Chilton  President  republican            15081
# 11   Choctaw  President  republican             4106
# 12    Clarke  President  republican             7140
# 13      Clay  President  republican             5245
# 14  Cleburne  President  republican             5764

# %%
all_parties_df = pd.merge(democrat_republican_df,voter_df2.loc[voter_df3['party']== 'Other',:],on='FIPS',how='right')

all_parties_df
# Out:
#       FIPS  state_x     county_x   office_x   party_x candidatevotes_x  \
# 0     1001  Alabama      Autauga  President  democrat             5936
# 1     1003  Alabama      Baldwin  President  democrat            18458
# 2     1005  Alabama      Barbour  President  democrat             4871
# 3     1007  Alabama         Bibb  President  democrat             1874
# 4     1009  Alabama       Blount  President  democrat             2156
# ...    ...      ...          ...        ...       ...              ...
# 3177  2037   Alaska  District 37  President  democrat             2421
# 3178  2038   Alaska  District 38  President  democrat             2758
# 3179  2039   Alaska  District 39  President  democrat             3142
# 3180  2040   Alaska  District 40  President  democrat             2338
# 3181  2099   Alaska  District 99  President  democrat              274
#
#       state_y     county_y   office_y     party_y candidatevotes_y    state  \
# 0     Alabama      Autauga  President  republican            18172  Alabama
# 1     Alabama      Baldwin  President  republican            72883  Alabama
# 2     Alabama      Barbour  President  republican             5454  Alabama
# 3     Alabama         Bibb  President  republican             6738  Alabama
# 4     Alabama       Blount  President  republican            22859  Alabama
# ...       ...          ...        ...         ...              ...      ...
# 3177   Alaska  District 37  President  republican             1938   Alaska
# 3178   Alaska  District 38  President  republican             1143   Alaska
# 3179   Alaska  District 39  President  republican             1405   Alaska
# 3180   Alaska  District 40  President  republican             1377   Alaska
# 3181   Alaska  District 99  President  republican               40   Alaska
#
#            county     office  party candidatevotes
# 0         Autauga  President  Other            865
# 1         Baldwin  President  Other           3874
# 2         Barbour  President  Other            144
# 3            Bibb  President  Other            207
# 4          Blount  President  Other            573
# ...           ...        ...    ...            ...
# 3177  District 37  President  Other            703
# 3178  District 38  President  Other           1194
# 3179  District 39  President  Other           1092
# 3180  District 40  President  Other            895
# 3181  District 99  President  Other             28
#
# [3182 rows x 16 columns]

# %%
# Drop duplicate rows, narrow columns, and rename columns

all_parties_df = all_parties_df.drop_duplicates()

all_parties_df
# Out:
#       FIPS  state_x     county_x   office_x   party_x candidatevotes_x  \
# 0     1001  Alabama      Autauga  President  democrat             5936
# 1     1003  Alabama      Baldwin  President  democrat            18458
# 2     1005  Alabama      Barbour  President  democrat             4871
# 3     1007  Alabama         Bibb  President  democrat             1874
# 4     1009  Alabama       Blount  President  democrat             2156
# ...    ...      ...          ...        ...       ...              ...
# 3177  2037   Alaska  District 37  President  democrat             2421
# 3178  2038   Alaska  District 38  President  democrat             2758
# 3179  2039   Alaska  District 39  President  democrat             3142
# 3180  2040   Alaska  District 40  President  democrat             2338
# 3181  2099   Alaska  District 99  President  democrat              274
#
#       state_y     county_y   office_y     party_y candidatevotes_y    state  \
# 0     Alabama      Autauga  President  republican            18172  Alabama
# 1     Alabama      Baldwin  President  republican            72883  Alabama
# 2     Alabama      Barbour  President  republican             5454  Alabama
# 3     Alabama         Bibb  President  republican             6738  Alabama
# 4     Alabama       Blount  President  republican            22859  Alabama
# ...       ...          ...        ...         ...              ...      ...
# 3177   Alaska  District 37  President  republican             1938   Alaska
# 3178   Alaska  District 38  President  republican             1143   Alaska
# 3179   Alaska  District 39  President  republican             1405   Alaska
# 3180   Alaska  District 40  President  republican             1377   Alaska
# 3181   Alaska  District 99  President  republican               40   Alaska
#
#            county     office  party candidatevotes
# 0         Autauga  President  Other            865
# 1         Baldwin  President  Other           3874
# 2         Barbour  President  Other            144
# 3            Bibb  President  Other            207
# 4          Blount  President  Other            573
# ...           ...        ...    ...            ...
# 3177  District 37  President  Other            703
# 3178  District 38  President  Other           1194
# 3179  District 39  President  Other           1092
# 3180  District 40  President  Other            895
# 3181  District 99  President  Other             28
#
# [3182 rows x 16 columns]

# %%
# Clean all_parties_df

all_parties_cleaned = all_parties_df[['FIPS','state_x','county_x','office_x','candidatevotes_x','candidatevotes_y','candidatevotes']]

# %%
all_parties_cleaned2 = all_parties_cleaned.rename(columns = {'state_x':'state','county_x':'county','office_x':'office','candidatevotes_x':'Democrat Votes','candidatevotes_y':'Republican Votes','candidatevotes':'Other Votes'})


all_parties_cleaned2
# Out:
#       FIPS    state       county     office Democrat Votes Republican Votes  \
# 0     1001  Alabama      Autauga  President           5936            18172
# 1     1003  Alabama      Baldwin  President          18458            72883
# 2     1005  Alabama      Barbour  President           4871             5454
# 3     1007  Alabama         Bibb  President           1874             6738
# 4     1009  Alabama       Blount  President           2156            22859
# ...    ...      ...          ...        ...            ...              ...
# 3177  2037   Alaska  District 37  President           2421             1938
# 3178  2038   Alaska  District 38  President           2758             1143
# 3179  2039   Alaska  District 39  President           3142             1405
# 3180  2040   Alaska  District 40  President           2338             1377
# 3181  2099   Alaska  District 99  President            274               40
#
#      Other Votes
# 0            865
# 1           3874
# 2            144
# 3            207
# 4            573
# ...          ...
# 3177         703
# 3178        1194
# 3179        1092
# 3180         895
# 3181          28
#
# [3182 rows x 7 columns]

# %%
#### Final Tables for Load Process (Overall Summary)
## County Unemployment DataFrame

county_unemployment_df
# Out:
#      FIPS             county  Latest Annual Unemployment Rate (2019)  \
# 1    1001     Autauga County                                     2.7
# 2    1003     Baldwin County                                     2.7
# 3    1005     Barbour County                                     3.8
# 4    1007        Bibb County                                     3.1
# 5    1009      Blount County                                     2.7
# ..    ...                ...                                     ...
# 19  56037  Sweetwater County                                     3.9
# 20  56039       Teton County                                     2.7
# 21  56041       Uinta County                                     3.9
# 22  56043    Washakie County                                     3.9
# 23  56045      Weston County                                     2.9
#
#     Median Household Income (2018)  % of State Median HH Income
# 1                          59338.0                     1.189591
# 2                          57588.0                     1.154508
# 3                          34382.0                     0.689280
# 4                          46064.0                     0.923478
# 5                          50412.0                     1.010645
# ..                             ...                          ...
# 19                         73315.0                     1.177581
# 20                         99087.0                     1.591529
# 21                         63401.0                     1.018343
# 22                         55190.0                     0.886458
# 23                         54319.0                     0.872468
#
# [3135 rows x 5 columns]

# %%
## State Unemployment DataFrame

state_unemployment_df
# Out:
#     FIPS                 State  Latest Annual Unemployment Rate (2019)  \
# 0   1000               Alabama                                     3.0
# 0   2000                Alaska                                     6.1
# 0   4000               Arizona                                     4.7
# 0   5000              Arkansas                                     3.5
# 0   6000            California                                     4.0
# 0   8000              Colorado                                     2.8
# 0   9000           Connecticut                                     3.7
# 0  10000              Delaware                                     3.8
# 0  11000  District of Columbia                                     5.5
# 0  12000               Florida                                     3.1
# 0  13000               Georgia                                     3.4
# 0  15000                Hawaii                                     2.7
# 0  16000                 Idaho                                     2.9
# 0  17000              Illinois                                     4.0
# 0  18000               Indiana                                     3.3
# 0  19000                  Iowa                                     2.7
# 0  20000                Kansas                                     3.2
# 0  21000              Kentucky                                     4.3
# 0  22000             Louisiana                                     4.8
# 0  23000                 Maine                                     3.0
# 0  24000              Maryland                                     3.6
# 0  25000         Massachusetts                                     2.9
# 0  26000              Michigan                                     4.1
# 0  27000             Minnesota                                     3.2
# 0  28000           Mississippi                                     5.4
# 0  29000              Missouri                                     3.3
# 0  30000               Montana                                     3.5
# 0  31000              Nebraska                                     3.0
# 0  32000                Nevada                                     3.9
# 0  33000         New Hampshire                                     2.5
# 0  34000            New Jersey                                     3.6
# 0  35000            New Mexico                                     4.9
# 0  36000              New York                                     4.0
# 0  37000        North Carolina                                     3.9
# 0  38000          North Dakota                                     2.4
# 0  39000                  Ohio                                     4.1
# 0  40000              Oklahoma                                     3.3
# 0  41000                Oregon                                     3.7
# 0  42000          Pennsylvania                                     4.4
# 0  72000           Puerto Rico                                     8.3
# 0  44000          Rhode Island                                     3.6
# 0  45000        South Carolina                                     2.8
# 0  46000          South Dakota                                     3.3
# 0  47000             Tennessee                                     3.4
# 0  48000                 Texas                                     3.5
# 0  49000                  Utah                                     2.6
# 0  50000               Vermont                                     2.4
# 0  51000              Virginia                                     2.8
# 0  53000            Washington                                     4.3
# 0  54000         West Virginia                                     4.9
# 0  55000             Wisconsin                                     3.3
# 0  56000               Wyoming                                     3.6
#
#    Median Household Income (2018)  % of State Median HH Income
# 0                         49881.0                          1.0
# 0                         74912.0                          1.0
# 0                         59079.0                          1.0
# 0                         47094.0                          1.0
# 0                         75250.0                          1.0
# 0                         71949.0                          1.0
# 0                         76366.0                          1.0
# 0                         65467.0                          1.0
# 0                         82533.0                          1.0
# 0                         55433.0                          1.0
# 0                         58634.0                          1.0
# 0                         80527.0                          1.0
# 0                         55524.0                          1.0
# 0                         65063.0                          1.0
# 0                         55725.0                          1.0
# 0                         60071.0                          1.0
# 0                         58150.0                          1.0
# 0                         50189.0                          1.0
# 0                         48021.0                          1.0
# 0                         55579.0                          1.0
# 0                         83076.0                          1.0
# 0                         79817.0                          1.0
# 0                         56640.0                          1.0
# 0                         70295.0                          1.0
# 0                         44740.0                          1.0
# 0                         54412.0                          1.0
# 0                         55248.0                          1.0
# 0                         59724.0                          1.0
# 0                         58740.0                          1.0
# 0                         75322.0                          1.0
# 0                         81777.0                          1.0
# 0                         47405.0                          1.0
# 0                         67648.0                          1.0
# 0                         53922.0                          1.0
# 0                         65250.0                          1.0
# 0                         56155.0                          1.0
# 0                         51914.0                          1.0
# 0                         63168.0                          1.0
# 0                         60891.0                          1.0
# 0                             NaN                          NaN
# 0                         63787.0                          1.0
# 0                         52449.0                          1.0
# 0                         57041.0                          1.0
# 0                         52366.0                          1.0
# 0                         60632.0                          1.0
# 0                         71381.0                          1.0
# 0                         60917.0                          1.0
# 0                         72600.0                          1.0
# 0                         74023.0                          1.0
# 0                         44038.0                          1.0
# 0                         60779.0                          1.0
# 0                         62259.0                          1.0

# %%
## Voter breakdown by county

all_parties_cleaned2
# Out:
#       FIPS    state       county     office Democrat Votes Republican Votes  \
# 0     1001  Alabama      Autauga  President           5936            18172
# 1     1003  Alabama      Baldwin  President          18458            72883
# 2     1005  Alabama      Barbour  President           4871             5454
# 3     1007  Alabama         Bibb  President           1874             6738
# 4     1009  Alabama       Blount  President           2156            22859
# ...    ...      ...          ...        ...            ...              ...
# 3177  2037   Alaska  District 37  President           2421             1938
# 3178  2038   Alaska  District 38  President           2758             1143
# 3179  2039   Alaska  District 39  President           3142             1405
# 3180  2040   Alaska  District 40  President           2338             1377
# 3181  2099   Alaska  District 99  President            274               40
#
#      Other Votes
# 0            865
# 1           3874
# 2            144
# 3            207
# 4            573
# ...          ...
# 3177         703
# 3178        1194
# 3179        1092
# 3180         895
# 3181          28
#
# [3182 rows x 7 columns]
